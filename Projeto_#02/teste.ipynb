# %%
import pandas as pd 

tabela = pd.read_csv("cancelamentos_sample.csv")

#tabela = tabela.drop(columns="CustomerID", "sexo" ,"idade",)
nan = ["CustomerID", "sexo" ,"idade" , "tempo_como_cliente",	"frequencia_uso"	,"ligacoes_callcenter"	,"dias_atraso",	"assinatura",	"duracao_contrato" ,"meses_ultima_interacao","cancelou"]
tabela_modificada = tabela.drop(nan, axis=1)

# Exibindo o DataFrame modificado
display(tabela_modificada .sum())
display(tabela)
# Out:
# total_gasto    31587880.62
# dtype: float64
#        CustomerID  idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0        349936.0   23.0    Male                13.0            22.0
# 1        100634.0   49.0    Male                55.0            16.0
# 2        301263.0   30.0    Male                 7.0             1.0
# 3        119358.0   26.0    Male                40.0             5.0
# 4        130955.0   27.0  Female                17.0            30.0
# ...           ...    ...     ...                 ...             ...
# 49995    195680.0   62.0  Female                35.0             7.0
# 49996     43477.0   36.0    Male                43.0            21.0
# 49997    169273.0   55.0    Male                42.0             8.0
# 49998    310693.0   40.0  Female                14.0            19.0
# 49999    251915.0   64.0    Male                41.0            29.0
#
#        ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# ...

# %%
import pandas as pd

# Carregando o DataFrame
tabela = pd.read_csv("cancelamentos_sample.csv")

# Selecionando linhas e colunas desejadas
#tabela_selecionada = tabela[(tabela['total_gasto'] > 100)][['sexo', 'idade', 'tempo_como_cliente']]
tabela_selecionada = tabela[(tabela['total_gasto'] > 100)][['total_gasto']]

# Exibindo o DataFrame selecionado
#display(tabela_selecionada)#
display(tabela['total_gasto'].value_counts(normalize=True))
display(tabela.groupby("total_gasto").mean(numeric_only=True))
# Out:
# total_gasto
# 918.00    0.00088
# 331.00    0.00086
# 410.00    0.00082
# 307.00    0.00080
# 660.00    0.00078
#            ...
# 906.25    0.00002
# 744.28    0.00002
# 997.26    0.00002
# 851.08    0.00002
# 700.38    0.00002
# Name: proportion, Length: 22488, dtype: float64
#                 CustomerID      idade  tempo_como_cliente  frequencia_uso  \
# total_gasto
# 100.00       115631.538462  42.692308           31.615385       16.230769
# 100.25       238068.000000  44.000000           14.000000        9.000000
# 100.26       214843.000000  48.000000           18.000000        4.000000
# 100.59       243186.000000  36.500000           32.000000       10.500000
# 100.75       210477.000000  38.000000            1.000000        8.000000
# ...                    ...        ...                 ...             ...
# 999.88       323018.500000  37.500000           28.000000       22.000000
# 999.95       400448.000000  26.000000           56.000000       13.000000
# ...
